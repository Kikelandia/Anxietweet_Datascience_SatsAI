# %%
import pandas as pd
import boto3
import requests
from io import StringIO
from botocore.client import Config
from smart_open import smart_open

import random

import string
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split

import pickle

pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Loading Data

# %%
root_tweet_clean = pd.read_csv('Datos1_Kike/tweets_cleaned_labeled.csv')

# %%
root_tweet_clean
# Out:
#                                                                                                                                                                                                                                                                                            text  \
# 0                                                                                                                                                                                                                             Coronavirus: No new deaths and 727 new cases confirmed in Ireland
# 1                                                                                            This was definitely a Grenade tweet just lobbed into twittersphere for people to go mad at.There can’t be anyway that you think the sectors you’ve mentioned have shaped the covid response/policy
# 2                                                                                                                                                                                                                                                      Everyone in Kolkata now is Covid Aladin.
# 3                                                                                    Becky's mother hasn't held her granddaughter yet.Balor's father went through COVID-19 and triple heart bypass surgery.Both parents are IT to each of them.And I am sure there's a great many stories more.
# 4                                                                                                                                                                    2020 has been crazy year, bought a house at 27 with my partner, Got married and Got covid. it's been a rollercoaster year.
# ...                                                                                                                                                                                                                                                                                         ...
# 51995  Of course, because who doesn't love a leader who failed to prevent a second COVID-19 wave he knew was coming? It's not like other countries have gotten a handle on this pandemic, proving it's possible while exposing Canada's response as a woefully inadequate deadly embarrassment.
# 51996                                                                                                                                                                                                             French President Emmanuel Macron tests positive for coronavirus - National |
# 51997                               My god. Will somebody please help untwist his shorts? You sit on your fucking hands instead of helping Americans deal with Covid, you tolerate Trump's racism and sexism but you get bent out of shape because you're called a fucker? You fucking #fucker.
# 51998                                                                                               Those who were abandoning wells anyway [are] the ones who are taking advantage of this federal program, Dorin told Global News in an interview. In other words we're not creating any jobs.
# 51999                                                                                                                                                                                                              #MidnightMass Covid safety zones in Vancouver. Red zone = performance zone.
#
#                                                                                                                                                                                                clean_text  \
# 0                                                                                                                                                  coronavirus new deaths 727 new cases confirmed ireland
# 1                                                             definitely grenade tweet lobbed twittersphere people go mad atthere can’t anyway think sectors you’ve mentioned shaped covid responsepolicy
# 2                                                                                                                                                                           everyone kolkata covid aladin
# 3                                                     beckys mother hasnt held granddaughter yetbalors father went covid19 triple heart bypass surgeryboth parents themand sure theres great many stories
# 4                                                                                                                        2020 crazy year bought house 27 partner got married got covid rollercoaster year
# ...                                                                                                                                                                                                   ...
# 51995  course doesnt love leader failed prevent second covid19 wave knew coming like countries gotten handle pandemic proving possible exposing canadas response woefully inadequate deadly embarrassment
# 51996                                                                                                                                french president emmanuel macron tests positive coronavirus national
# 51997                      god somebody please help untwist shorts sit fucking hands instead helping americans deal covid tolerate trumps racism sexism get bent shape youre called fucker fucking fucker
# 51998                                                                                  abandoning wells anyway ones taking advantage federal program dorin told global news interview words creating jobs
# 51999                                                                                                                                 midnightmass covid safety zones vancouver red zone performance zone
#
#        class
# 0         -1
# 1         -1
# 2          0
# 3          1
# 4         -1
# ...      ...
# 51995     -1
# 51996      1
# 51997     -1
# 51998     -1
# 51999      1
#
# [52000 rows x 3 columns]

# %%
def text_process(mess):
    """
    1. remove punc
    2. remove stop words
    3. return list of clean words
    """
    #print(mess)
    nopunc = [char for char in str(mess) if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    nopunc = [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    
    return(nopunc)

# %%
root_tweet_clean['new_treat']=root_tweet_clean.clean_text.apply(text_process)
root_tweet_clean['new_treat'] = [' '.join(map(str, l)) for l in root_tweet_clean['new_treat']]

# %% [markdown]
# ## Creating the  "Bag of Words" transformer
#
# With the cleanning function previously created

# %%
bow_transformer = CountVectorizer().fit(root_tweet_clean['new_treat'])

# %%
print(len(bow_transformer.vocabulary_))
# Out:
# 60474

# %%
bow_transformer.vocabulary_
# Out:
# {'coronavirus': 14135,
#  'new': 37347,
#  'deaths': 16555,
#  '727': 3089,
#  'cases': 10997,
#  'confirmed': 13540,
#  'ireland': 29209,
#  'definitely': 16882,
#  'grenade': 24980,
#  'tweet': 55727,
#  'lobbed': 32900,
#  'twittersphere': 55786,
#  'people': 40958,
#  'go': 24445,
#  'mad': 33623,
#  'atthere': 6820,
#  'can': 10574,
#  'anyway': 5959,
#  'think': 53890,
#  'sectors': 48132,
#  'you': 60136,
#  've': 57349,
#  'mentioned': 35000,
#  'shaped': 48751,
#  'covid': 14513,
#  'responsepolicy': 45703,
#  'everyone': 20863,
#  'kolkata': 31298,
#  'aladin': 4842,
#  'beckys': 7920,
#  'mother': 36276,
#  'hasnt': 25804,
#  'held': 26173,
#  'granddaughter': 24825,
#  'yetbalors': 60069,
#  'father': 21758,
#  'went': 58674,
#  'covid19': 14524,
#  'triple': 55299,
#  'heart': 26075,
#  'bypass': 10328,
#  'surgeryboth': 52255,
#  'parents': 40355,
#  'themand': 53653,
#  'sure': 52226,
#  'theres': 53784,
#  'great': 24905,
#  'many': 33992,
#  'stories': 51497,
#  '2020': 1292,
#  'crazy': 15319,
#  'year': 59930,
#  'bought': 9344,
#  'house': 27150,
#  '27': 1745,
#  'partner': 40446,
#  'got': 24677,
#  'married': 34187,
#  'rollercoaster': 46517,
#  'heres': 26326,
#  'thing': 53869,
#  'lot': 33237,
#  'isnt': 29362,
#  'technically': 53092,
#  'relief': 45148,
#  'omnibus': 39009,
#  'take': 52723,
#  'every': 20851,
#  'single': 49426,
#  'dollar': 18390,
#  'pork': 42205,
#  'add': 4150,
#  'together': 54507,
#  'divide': 18190,
#  'eligible': 19751,
#  'citizens': 12302,
#  'approx': 6152,
#  '150m': 715,
#  'wed': 58480,
#  'get': 24114,
#  'extra': 21299,
#  '40': 2306,
#  'affects': 4407,
#  'debt': 16652,
#  'stimulus': 51350,
#  'lax': 31910,
#  'dont': 18479,
#  'care': 10818,
#  'mutant': 36666,
#  'strain': 51543,
#  'uk': 55971,
#  'appeared': 6069,
#  'countries': 14382,
#  '2021': 1382,
#  'becoming': 7923,
#  'again': 4489,
#  'zero': 60313,
#  'pipe': 41583,
#  'dream': 18777,
#  'one': 39050,
#  'whole': 58922,
#  'month': 36086,
#  'deprived': 17205,
#  'us': 56826,
#  'last': 31739,
#  'months': 36094,
#  'nana': 36852,
#  'wish': 59200,
#  'known': 31262,
#  'saw': 47535,
#  'it': 29432,
#  'time': 54238,
#  'face': 21372,
#  'forever': 22913,
#  'testing': 53349,
#  'hauliers': 25842,
#  'another': 5748,
#  'nail': 36819,
#  'coffin': 12848,
#  'landbridge': 31631,
#  'coveney': 14485,
#  'urges': 56816,
#  'businesses': 10203,
#  'direct': 17765,
#  'ferries': 22036,
#  'europe': 20724,
#  'avoid': 7069,
#  'disruption': 18060,
#  'nah': 36813,
#  'scam': 47600,
#  'literally': 32730,
#  'switch': 52489,
#  'mood': 36123,
#  'careful': 10835,
#  'sanitising': 47328,
#  'wearing': 58445,
#  'masks': 34312,
#  'caring': 10868,
#  'back': 7226,
#  'either': 19611,
#  'genuinely': 24022,
#  'blessed': 8851,
#  'ain': 4721,
#  'getting': 24138,
#  'truth': 55523,
#  'bb': 7705,
#  'works': 59461,
#  'best': 8266,
#  'wildcard': 59024,
#  'help': 26207,
#  'next': 37508,
#  'blankdouble': 8805,
#  'gameweeksi': 23755,
#  'main': 33731,
#  'risk': 46265,
#  'strategy': 51595,
#  'gameweeks': 23754,
#  'happens': 25657,
#  'occasions': 38691,
#  'totally': 54768,
#  'possible': 42305,
#  'season': 48049,
#  'things': 53874,
#  'happen': 25635,
#  '19': 1030,
#  'players': 41791,
#  'could': 14331,
#  'covidinjuredlose': 14961,
#  'form': 22950,
#  'lose': 33214,
#  'place': 41656,
#  'team': 53042,
#  'ultimately': 56059,
#  'lead': 31958,
#  'using': 56906,
#  'hits': 26619,
#  'field': 22128,
#  '15': 704,
#  'double': 18579,
#  'gameweek': 23753,
#  'cw': 15886,
#  'covidhonestly': 14943,
#  'don': 18431,
#  'know': 31248,
#  'vaccination': 57043,
#  'timeline': 54254,
#  'estimates': 20613,
#  'make': 33763,
#  'less': 32231,
#  'hopefulon': 26956,
#  'hand': 25540,
#  'nice': 37574,
#  'idea': 27658,
#  'long': 33083,
#  'might': 35373,
#  'takeon': 52740,
#  'kinda': 31101,
#  'cement': 11407,
#  'that': 53480,
#  'this': 53929,
#  'isn': 29360,
#  'really': 44469,
#  'gonna': 24549,
#  'over': 39762,
#  'naomirwolf': 36890,
#  'response': 45692,
#  'terrible': 53284,
#  'compared': 13258,
#  'still': 51331,
#  'vastly': 57317,
#  'better': 8300,
#  'usa': 56836,
#  'highlights': 26469,
#  'appalling': 6048,
#  'country': 14395,
#  'first': 22349,
#  'years': 59980,
#  'actually': 4105,
#  'agree': 4622,
#  'wouldn': 59581,
#  'sign': 49270,
#  'way': 58344,
#  'presented': 42724,
#  'told': 54540,
#  'march': 34017,
#  'wouldnt': 59582,
#  'see': 48157,
#  'family': 21581,
#  'christmas': 12070,
#  'would': 59577,
#  'laughed': 31828,
#  'ridiculousness': 46142,
#  'notion': 38180,
#  'taught': 52941,
#  'ever': 20829,
#  'viruses': 57731,
#  'lightly': 32503,
#  'terrifying': 53290,
#  'knowing': 31255,
#  'clients': 12519,
#  'supported': 52185,
#  'contracted': 13885,
#  'presidentelect': 42743,
#  'bidens': 8422,
#  'incoming': 28213,
#  'cdc': 11311,
#  'director': 17777,
#  'acknowledging': 4014,
#  'importance': 28054,
#  'aerosol': 4373,
#  'transmission': 55034,
#  'covid19covid19ireland': 14580,
#  'smallest': 49803,
#  'population': 42180,
#  'lowest': 33315,
#  'density': 17117,
#  'irish': 29240,
#  'counties': 14376,
#  'probably': 42984,
#  'factors': 21438,
#  'low': 33299,
#  'prevalence': 42816,
#  'county': 14421,
#  'majority': 33758,
#  'happy': 25666,
#  'governments': 24724,
#  'handling': 25571,
#  'situations': 49513,
#  'happiness': 25663,
#  'index': 28305,
#  '13': 526,
#  '1939': 1062,
#  'according': 3933,
#  'recent': 44606,
#  'poll': 42079,
#  'nervtag': 37277,
#  'committee': 13163,
#  'england': 20168,
#  'suggests': 52003,
#  '70': 3031,
#  'infectious': 28457,
#  'president': 42738,
#  'trump': 55398,
#  'refuses': 44917,
#  'bill': 8482,
#  'amended': 5293,
#  'include': 28195,
#  '2000': 1224,
#  'american': 5315,
#  'workers': 59412,
#  'affected': 4398,
#  'panic': 40239,
#  'bet': 8280,
#  'liberals': 32364,
#  'hate': 25817,
#  'even': 20799,
#  'act': 4052,
#  'data': 16205,
#  'information': 28550,
#  'currently': 15802,
#  'least': 32038,
#  'negligent': 37196,
#  'potentially': 42400,
#  'catastrophic': 11138,
#  'wait': 58032,
#  'confirmation': 13538,
#  'b117': 7180,
#  'transmissible': 55030,
#  'implementing': 28035,
#  'control': 13920,
#  'measures': 34702,
#  'ethically': 20668,
#  'immoralcovid19ireland': 27936,
#  'never': 37336,
#  'understand': 56262,
#  'didn': 17577,
#  'try': 55535,
#  'seemed': 48178,
#  'like': 32513,
#  'logical': 33009,
#  'everything': 20874,
#  'normal': 38020,
#  'ridiculous': 46138,
#  'stage': 50882,
#  'fingers': 22278,
#  'crossed': 15549,
#  'second': 48097,
#  'half': 25459,
#  'lordnihilus616': 33184,
#  'soo': 50246,
#  'sad': 47026,
#  'extremely': 21316,
#  'breaking': 9548,
#  'living': 32809,
#  'barely': 7540,
#  'existing': 21094,
#  'torture': 54731,
#  'selfishness': 48264,
#  'pigheadedness': 41509,
#  'buy': 10282,
#  'grafton': 24799,
#  'street': 51638,
#  'online': 39138,
#  'away': 7099,
#  'rely': 45201,
#  'right': 46158,
#  'give': 24263,
#  'vaccine': 57057,
#  'screw': 47952,
#  'anyone': 5941,
#  'wear': 58417,
#  'olbermann': 38929,
#  'vs': 57959,
#  '42': 2369,
#  'screws': 47957,
#  'emerging': 19903,
#  'via': 57531,
#  'unfortunately': 56363,
#  'we': 58385,
#  'll': 32836,
#  'rid': 46124,
#  'vaccines': 57120,
#  'arrive': 6377,
#  'trust': 55510,
#  'selfish': 48260,
#  'dining': 17732,
#  'shopping': 49033,
#  'stores': 51492,
#  'going': 24507,
#  'pubs': 43535,
#  'wasn': 58260,
#  'life': 32437,
#  'apparently': 6056,
#  'covidiots': 14969,
#  'economic': 19380,
#  'recovery': 44720,
#  'depend': 17152,
#  'whether': 58838,
#  'able': 3750,
#  'situation': 49509,
#  'question': 43863,
#  'fact': 21421,
#  'believe': 8079,
#  'hoax': 26666,
#  'there': 53752,
#  'dying': 19186,
#  'around': 6352,
#  'corner': 14104,
#  'aloud': 5145,
#  'level5': 32289,
#  'slowly': 49766,
#  'beginning': 8007,
#  'thinking': 53900,
#  'maybe': 34515,
#  'sort': 50296,
#  'future': 23595,
#  'thisi': 53948,
#  'sympathy': 52567,
#  'weird': 58588,
#  'conspiratorial': 13727,
#  'persecution': 41119,
#  'complexes': 13332,
#  'saying': 47553,
#  'planning': 41732,
#  'elderly': 19664,
#  'vulnerable': 57984,
#  'relativesfriends': 45100,
#  'christmascovid': 12078,
#  'lethal': 32247,
#  'virus': 57716,
#  'loved': 33286,
#  'ones': 39089,
#  'moved': 36339,
#  'church': 12200,
#  'suit': 52013,
#  'events': 20813,
#  'nothing': 38152,
#  'stopping': 51460,
#  'moving': 36354,
#  'drcs': 18764,
#  'muddy': 36484,
#  'trails': 54939,
#  'lessons': 32242,
#  'covidvaccine': 15167,
#  'rollout': 46528,
#  'listenamplearn': 32703,
#  'nicudocsalone': 37627,
#  'dcusnpch': 16441,
#  'aidwkr': 4705,
#  'reiseal2': 45059,
#  'rekasztopa': 45074,
#  'carolmorgan11': 10921,
#  'dochasnetwork': 18285,
#  'ago': 4597,
#  'youd': 60147,
#  'labelled': 31483,
#  'conspiracy': 13723,
#  'theoristsuch': 53733,
#  'discrimination': 17896,
#  'split': 50616,
#  'society': 50078,
#  'vaxxed': 57335,
#  'unvaxxed': 56647,
#  'massive': 34374,
#  'public': 43498,
#  'pushback': 43659,
#  'depravity': 17192,
#  'thegreatresistance': 53620,
#  'nicolasturgeon': 37612,
#  'apologies': 6022,
#  'broke': 9837,
#  'rules': 46841,
#  'funeral': 23545,
#  'covid19covid19': 14578,
#  'reached': 44362,
#  'research': 45550,
#  'base': 7604,
#  'antarctica': 5772,
#  'thay': 53520,
#  'send': 48342,
#  'stamped': 50926,
#  'envelope': 20320,
#  'wuhan': 59730,
#  'dangerous': 16085,
#  'michael': 35205,
#  'fuck': 23414,
#  'bullshit': 10073,
#  'revolution': 45985,
#  'ppl': 42467,
#  'become': 7921,
#  'impossible': 28076,
#  'anything': 5949,
#  'position': 42270,
#  'suicide': 52008,
#  'crap': 15293,
#  'zealand': 60293,
#  'controlled': 13929,
#  'strict': 51679,
#  'lockdowns': 32965,
#  'australia': 6917,
#  'followed': 22762,
#  'example': 20965,
#  'thats': 53506,
#  'whats': 58789,
#  'defeated': 16831,
#  'isagcovid19': 29313,
#  'julienmercille': 30511,
#  'killeengerry': 31064,
#  'dazultpdempsey': 16415,
#  'tjryan77': 54393,
#  'nutters': 38475,
#  'angling': 5644,
#  'fir': 22310,
#  'extended': 21277,
#  'lockdown': 32944,
#  'cut': 15860,
#  'wrong': 59669,
#  'said': 47140,
#  'times': 54269,
#  'glad': 24292,
#  'mum': 36550,
#  'amp': 5389,
#  'dad': 15972,
#  'heaven': 26113,
#  'died': 17592,
#  'cancer': 10632,
#  'worst': 59557,
#  'thought': 54020,
#  'restricted': 45757,
#  'freedom': 23189,
#  'find': 22241,
#  'reacts': 44384,
#  'government': 24711,
#  'bans': 7505,
#  'pornography': 42220,
#  'ordinary': 39420,
#  'porn': 42215,
#  'dealing': 16505,
#  'crime': 15416,
#  'kingpins': 31124,
#  'facetimed': 21397,
#  'felleh': 21973,
#  'earlier': 19244,
#  'crying': 15635,
#  'frustrated': 23381,
#  'mess': 35075,
#  'restrictions': 45761,
#  'general': 23956,
#  'tiredness': 54350,
#  'casually': 11119,
#  'walked': 58079,
#  'so': 49998,
#  'won': 59331,
#  'hear': 26060,
#  'sneaking': 49932,
#  'sunday': 52058,
#  'morning': 36198,
#  'while': 58847,
#  'want': 58145,
#  'die': 17586,
#  'yes': 60040,
#  'others': 39549,
#  'locking': 32987,
#  'working': 59437,
#  'assumption': 6646,
#  'spread': 50705,
#  'given': 24268,
#  '10': 97,
#  'compound': 13364,
#  'daily': 15984,
#  'increase': 28249,
#  'safe': 47052,
#  'environment': 20327,
#  'glasthule': 24328,
#  'distribution': 18138,
#  'must': 36651,
#  'equitable': 20424,
#  'targeting': 52881,
#  'throughout': 54095,
#  'world': 59481,
#  'absolutely': 3815,
#  'beautiful': 7895,
#  'tradition': 54917,
#  'mummers': 36552,
#  'spilt': 50573,
#  'stop': 51442,
#  'saoirses': 47386,
#  'point': 41958,
#  'though': 54017,
#  'definitively': 16886,
#  'sided': 49224,
#  'attempt': 6787,
#  'push': 43658,
#  'business': 10198,
#  'agenda': 4545,
#  'clearly': 12483,
#  'rejected': 45065,
#  'holohan': 26782,
#  'rethink': 45844,
#  'plans': 41736,
#  '970': 3533,
#  'reportedvia': 45426,
#  'opening': 39245,
#  'restaurants': 45728,
#  'sit': 49493,
#  'meals': 34665,
#  'mixed': 35763,
#  'message': 35076,
#  'argentinian': 6277,
#  'embassador': 19873,
#  'requested': 45508,
#  'buried': 10146,
#  'foxford': 23065,
#  'co': 12740,
#  'mayo': 34525,
#  'birthplace': 8689,
#  'admiral': 4253,
#  'brown': 9888,
#  'pop': 42152,
#  'cant': 10695,
#  'fluvaccine': 22682,
#  'supposed': 52204,
#  'mostly': 36266,
#  'mistake': 35714,
#  'flu': 22635,
#  'enough': 20216,
#  'pfizer': 41261,
#  'making': 33783,
#  'profit': 43099,
#  'different': 17633,
#  'sales': 47182,
#  'prices': 42851,
#  'worldwide': 59516,
#  'indicate': 28322,
#  'pfizervaccine': 41277,
#  'interesting': 28929,
#  'spin': 50575,
#  'nphets': 38302,
#  'recommendation': 44666,
#  'open': 39226,
#  'far': 21641,
#  'mid': 35299,
#  'november': 38225,
#  '11220': 309,
#  'need': 37140,
#  'mask': 34274,
#  'visiting': 57779,
#  'relatives': 45099,
#  'auckland': 6853,
#  'homes': 26846,
#  'jacindaardern': 29648,
#  'ampteam': 5427,
#  'nursinghomes': 38452,
#  'visits': 57785,
#  'pls': 41874,
#  'learn': 32024,
#  'leovaradkar': 32214,
#  'eamonryan': 19238,
#  'hiqa': 26574,
#  'marybutlertd': 34249,
#  'boudicaoak': 9343,
#  'jamiebrysoncpni': 29750,
#  'two': 55791,
#  'virusescovid': 57732,
#  'brexithave': 9653,
#  'heard': 26063,
#  'fellow': 21975,
#  'retailers': 45823,
#  'amazing': 5248,
#  'job': 30151,
#  'keep': 30826,
#  'parttime': 40460,
#  'career': 10823,
#  'professional': 43083,
#  'cat': 11125,
#  'minder': 35498,
#  'gig': 24207,
#  'due': 19044,
#  'start': 50999,
#  'tomorrow': 54580,
#  'ruined': 46828,
#  'canceled': 10616,
#  'trip': 55294,
#  'longer': 33092,
#  'blaming': 8799,
#  'govt': 24748,
#  'allows': 5104,
#  'escape': 20535,
#  'blameit': 8797,
#  'brought': 9886,
#  'backit': 7257,
#  'obvious': 38676,
#  'looking': 33138,
#  'town': 54837,
#  'respecting': 45671,
#  'ho': 26657,
#  'hole': 26730,
#  'scientists': 47807,
#  'urgently': 56815,
#  'investigating': 29107,
#  'hints': 26561,
#  'variant': 57287,
#  'spreads': 50731,
#  'easily': 19287,
#  'childrenif': 11898,
#  'proven': 43360,
#  'account': 3936,
#  'significant': 49290,
#  'proportion': 43252,
#  'transmissioncovid19ireland': 55037,
#  'shouldn': 49099,
#  'complaining': 13308,
#  'retail': 45820,
#  'tough': 54791,
#  'hard': 25697,
#  'draining': 18729,
#  'especially': 20558,
#  'customers': 15850,
#  'rude': 46816,
#  'anger': 5631,
#  'moral': 36145,
#  'dilemma': 17700,
#  'policy': 42026,
#  'mths': 36454,
#  'discussed': 17901,
#  'willing': 59068,
#  'speak': 50447,
#  'difficult': 17643,
#  'address': 4176,
#  'pending': 40920,
#  'excuse': 21024,
#  'media': 34741,
#  'arguably': 6279,
#  'culpable': 15722,
#  'consideration': 13689,
#  'responsible': 45714,
#  'reportingyou': 45436,
#  'someone': 50197,
#  'rte': 46765,
#  'turn': 55666,
#  'say': 47544,
#  'do': 18274,
#  'noon': 37984,
#  'night': 37650,
#  'premier': 42657,
#  'league': 31991,
#  'taking': 52756,
#  'limit': 32565,
#  'visualised': 57793,
#  'tracker': 54884,
#  'since': 49402,
#  'dr': 18706,
#  'pierre': 41493,
#  'kory': 31319,
#  'senate': 48323,
#  'testimony': 53347,
#  'early': 19249,
#  'treatments': 55182,
#  'latest': 31778,
#  'news': 37407,
#  'thanks': 53462,
#  'newsletter': 37447,
#  'eu': 20699,
#  'millybar': 35473,
#  'nightly': 37661,
#  'good': 24557,
#  'okya': 38926,
#  'challenging': 11555,
#  'landscape': 31642,
#  'mitigation': 35759,
#  'changes': 11600,
#  'much': 36464,
#  'monthly': 36092,
#  'plan': 41701,
#  'argument': 6285,
#  'weak': 58386,
#  'ok': 38902,
#  'tooth': 54661,
#  'fairy': 21511,
#  'isolate': 29365,
#  '14days': 688,
#  'kperkctc': 31335,
#  'parasites': 40329,
#  'kill': 31059,
#  'cells': 11399,
#  'severe': 48568,
#  'sick': 49200,
#  're': 44356,
#  'perfectly': 41050,
#  'levels': 32294,
#  'present': 42720,
#  'young': 60166,
#  'struck': 51723,
#  'almost': 5130,
#  'urgent': 56814,
#  'participated': 40420,
#  'event': 20806,
#  'net': 37286,
#  'fest': 22047,
#  'ukraine': 56024,
#  'missed': 35683,
#  'connect': 13627,
#  'collaborate': 12935,
#  'meet': 34837,
#  'share': 48758,
#  'innovative': 28692,
#  'technologies': 53101,
#  'favorites': 21803,
#  'free': 23180,
#  'timemvpbuzz': 54262,
#  'socially': 50062,
#  'distanced': 18089,
#  'cheer': 11771,
#  'lights': 32507,
#  'dlrcoco': 18245,
#  'digitaldunlaoghaire': 17669,
#  'super': 52088,
#  'likely': 32528,
#  'stopped': 51457,
#  'practicing': 42491,
#  'preventative': 42822,
#  'cuase': 15685,
#  'winter': 59153,
#  'antcon7062': 5782,
#  'gp': 24761,
#  'school': 47722,
#  'principal': 42891,
#  'nurse': 38435,
#  'medical': 34759,
#  'student': 51752,
#  'apart': 5987,
#  'drdeclank': 18769,
#  'well': 58615,
#  'sounds': 50333,
#  'kind': 31100,
#  'book': 9181,
#  'im': 27880,
#  'also': 5166,
#  'hoping': 26965,
#  'little': 32747,
#  'anxieties': 5916,
#  'disappear': 17804,
#  'smothered': 49890,
#  'shadow': 48671,
#  'enjoy': 20196,
#  'improved': 28100,
#  'deep': 16802,
#  'supercovid': 52095,
#  'strip': 51695,
#  'readied': 44396,
#  'blue': 8959,
#  'passports': 40522,
#  '1nplay': 1189,
#  'sent': 48391,
#  'work': 59397,
#  'day': 16335,
#  'answered': 5764,
#  'questions': 43870,
#  'email': 19848,
#  'beforeafter': 7980,
#  'rest': 45719,
#  'busy': 10234,
#  '31': 1954,
#  'children': 11896,
#  'room': 46593,
#  'constantly': 13731,
#  'teaching': 53039,
#  'amongst': 5381,
#  'issues': 29406,
#  'crop': 15537,
#  'minutes': 35576,
#  '22': 1539,
#  'cabinet': 10358,
#  'appoints': 6116,
#  '20': 1222,
#  'special': 50461,
#  'advisers': 4352,
#  'tighter': 54210,
#  'introduced': 29052,
#  'gravy': 24897,
#  'train': 54940,
#  'carriages': 10936,
#  'shameless': 48710,
#  'aunt': 6886,
#  'admitted': 4262,
#  'hospital': 27029,
#  'kindney': 31109,
#  'issue': 29399,
#  'knowledge': 31258,
#  'placed': 41664,
#  'ward': 58162,
#  'positive': 42276,
#  'patients': 40593,
#  'subsequently': 51879,
#  'passed': 40491,
#  'backs': 7272,
#  'wanna': 58143,
#  'nathan': 36951,
#  'sykes': 52547,
#  'jimmfelton': 30090,
#  'rubbish': 46802,
#  'nobody': 37795,
#  'france': 23104,
#  'gives': 24274,
#  'toss': 54751,
#  'brexit': 9640,
#  'trade': 54901,
#  'deal': 16496,
#  'reporting': 45433,
#  'game': 23730,
#  'struggle': 51730,
#  'industries': 28376,
#  'lost': 33234,
#  'vintners': 57660,
#  'airlinesat': 4768,
#  'height': 26157,
#  'easing': 19288,
#  'gov': 24696,
#  'advice': 4336,
#  'wet': 58722,
#  'staycations': 51117,
#  'spire': 50593,
#  'connell': 13641,
#  'metal': 35103,
#  'monolith': 36055,
#  'symbol': 52554,
#  'vaccinations': 57049,
#  'utahmonolith': 56953,
#  'eve': 20789,
#  'without': 59234,
#  'drinks': 18827,
#  'pub': 43492,
#  'irelandunderlockdown': 29232,
#  'kicking': 31017,
#  '1500': 706,
#  'jacket': 29660,
#  'yet': 60065,
#  'panels': 40229,
#  'bed': 7929,
#  'mams': 33857,
#  'box': 9385,
#  'falling': 21542,
#  'spent': 50540,
#  'ur': 56803,
#  'payments': 40735,
#  'parka': 40366,
#  'designed': 17288,
#  'artic': 6418,
#  'lads': 31548,
#  'spend': 50528,
#  '30': 1899,
#  'quid': 43900,
#  'mam': 33840,
#  'xmas': 59811,
#  'ahhahaha': 4661,
#  'ciananbrennan': 12212,
#  'average': 7036,
#  'flights': 22543,
#  'london': 33050,
#  'airports': 4782,
#  'dublin': 19008,
#  'pre': 42530,
#  'lets': 32256,
#  'reduced': 44820,
#  'reductions': 44825,
#  'schedule': 47689,
#  '180': 925,
#  '18': 924,
#  'days': 16365,
#  'paper': 40280,
#  'total': 54759,
#  'number': 38400,
#  'operated': 39270,
#  '1st18th': 1201,
#  'kaygord22721554': 30786,
#  'oliveblogs': 38962,
#  'ruthstoutter': 46947,
#  'schools': 47746,
#  'safeits': 47067,
#  'thankfully': 53458,
#  'mild': 35418,
#  'asymptomaticwithout': 6711,
#  'mass': 34357,
#  'true': 55380,
#  'china': 11928,
#  'person': 41135,
#  'questioning': 43867,
#  'spelled': 50521,
#  '170': 867,
#  'wrongbrexit': 59672,
#  'borisjohnson': 9279,
#  'britain': 9770,
#  'politics': 42065,
#  'brexitmemes': 9657,
#  'british': 9784,
#  'britishmeme': 9791,
#  'ukpolitics': 56022,
#  'conservative': 13681,
#  'unitedkingdom': 56432,
#  'conservatives': 13682,
#  'scotland': 47869,
#  'ukmemes': 56014,
#  'peoplesvote': 41005,
#  'labour': 31499,
#  'revokearticle': 45979,
#  'fbpe': 21831,
#  'brexitmeansbrexit': 9656,
#  'tackled': 52667,
#  'economy': 19396,
#  'based': 7606,
#  'shops': 49035,
#  'gyms': 25341,
#  'etc': 20630,
#  'rather': 44259,
#  'assessing': 6589,
#  'premises': 42666,
#  'proof': 43215,
#  'airhandling': 4753,
#  'paid': 40060,
#  'price': 42849,
#  ...}

# %%
messages_bow = bow_transformer.transform(root_tweet_clean['new_treat'])

# %%
messages_bow.shape
# Out:
# (52000, 60474)

# %% [markdown]
# ## Sparsity
#
# Used to determine the amount of zero coefficients inside our DF

# %%
sparsity = ( 100.0 * messages_bow.nnz / (messages_bow.shape[0] * messages_bow.shape[1] ) )
print('Sparsity: {}'.format(sparsity))
# Out:
# Sparsity: 0.023024675575771914

# %% [markdown]
# ## TF-IDF
#
# Tranformer which objective is to determine how relevant/important a word is, from the document the same word belongs to, document can be called "Corpus" as well

# %%
tfidf_transformer = TfidfTransformer().fit(messages_bow)

# %%
tfidf_transformer.idf_[bow_transformer.vocabulary_['university']]
# Out:
# 7.541530114611576

# %%
messages_tfidf = tfidf_transformer.transform(messages_bow)

# %% [markdown]
# ## Random Forest Model
#
# Is suitable for dealing with a high dimensional problem such as text representation, also it can discern between noisy data inside the text calssification

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(
                                                messages_tfidf,
                                                root_tweet_clean['class'],
                                                test_size=0.33,
                                                random_state=42)

stress_detect_model = RandomForestClassifier(random_state=42, n_jobs = -1)
stress_detect_model.fit(X_train,y_train)
stress_detect_model.score(X_test,y_test)
# Out:
# 0.724009324009324

# %%
mess4 = root_tweet_clean['new_treat'][3]
print(mess4)
# Out:
# beckys mother hasnt held granddaughter yetbalors father went covid19 triple heart bypass surgeryboth parents themand sure theres great many stories

# %% [markdown]
# Checking the BoW transformation

# %%
bow4 = bow_transformer.transform([mess4])
print(bow4)
# Out:
#   (0, 7920)	1
#   (0, 10328)	1
#   (0, 14524)	1
#   (0, 21758)	1
#   (0, 24825)	1
#   (0, 24905)	1
#   (0, 25804)	1
#   (0, 26075)	1
#   (0, 26173)	1
#   (0, 33992)	1
#   (0, 36276)	1
#   (0, 40355)	1
#   (0, 51497)	1
#   (0, 52226)	1
#   (0, 52255)	1
#   (0, 53653)	1
#   (0, 53784)	1
#   (0, 55299)	1
#   (0, 58674)	1
#   (0, 60069)	1

# %% [markdown]
# Checking the tf idf transformation

# %%
tfidf4 = tfidf_transformer.transform(bow4)
print(tfidf4)
# Out:
#   (0, 60069)	0.30792539006155484
#   (0, 58674)	0.16026993048212637
#   (0, 55299)	0.26644688676241896
#   (0, 53784)	0.16928939717357022
#   (0, 53653)	0.30792539006155484
#   (0, 52255)	0.30792539006155484
#   (0, 52226)	0.15003892486792286
#   (0, 51497)	0.18476737636473342
#   (0, 40355)	0.18322634012362005
#   (0, 36276)	0.1964286574393601
#   (0, 33992)	0.12665982518870555
#   (0, 26173)	0.20174843378126223
#   (0, 26075)	0.18606537466494688
#   (0, 25804)	0.20872096827538367
#   (0, 24905)	0.14544932041159642
#   (0, 24825)	0.2888102117620441
#   (0, 21758)	0.21506421716405671
#   (0, 14524)	0.06127618483850081
#   (0, 10328)	0.2776285492622315
#   (0, 7920)	0.30792539006155484

# %%
stress_detect_model.predict(tfidf4)[0]
# Out:
# 1

# %%
all_pred = stress_detect_model.predict(messages_tfidf)
all_pred
# Out:
# array([-1, -1,  0, ..., -1, -1,  1])

# %%
msg_train,msg_test,label_train,label_test = train_test_split(root_tweet_clean['new_treat'],root_tweet_clean['class'],test_size=0.2)

# %% [markdown]
# ## Pipeline Creation
#
# It is used to minimize the use of code, and can be stored to export it to a different application or system

# %%
from sklearn.pipeline import Pipeline

# %%
pipeline = Pipeline([
    ('bow',CountVectorizer(analyzer=text_process)),
    ('tfidf',TfidfTransformer()),
    ('classifier',RandomForestClassifier(random_state=42, n_jobs = -1))
])

# %%
pipeline.fit(msg_train,label_train)
# Out:
# Pipeline(steps=[('bow',
#                  CountVectorizer(analyzer=<function text_process at 0x7f8aa8565b70>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('classifier',
#                  RandomForestClassifier(n_jobs=-1, random_state=42))])

# %%
prediction = pipeline.predict(msg_test)

# %%
from sklearn.metrics import classification_report
print( classification_report(label_test,prediction) )
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.76      0.84      0.79      5262
#            0       0.67      0.75      0.71      3102
#            1       0.77      0.41      0.54      2036
#
#     accuracy                           0.73     10400
#    macro avg       0.73      0.67      0.68     10400
# weighted avg       0.73      0.73      0.72     10400

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(label_test, prediction)
# Out:
# array([[4401,  679,  182],
#        [ 695, 2333,   74],
#        [ 719,  473,  844]])

# %%
from sklearn.metrics import precision_score
precision_score(label_test, prediction,average='weighted')
# Out:
# 0.7328116727231215

# %%
predictiontrn = pipeline.predict(msg_train)

# %%
precision_score(label_train, predictiontrn,average='weighted')
# Out:
# 0.999399523133785

# %%
root_tweet_clean['class'].value_counts()
# Out:
# -1    26028
#  0    15714
#  1    10258
# Name: class, dtype: int64

# %%
print(len(label_test),len(label_train))
# Out:
# 10400 41600

# %%
root_tweet_clean
# Out:
#                                                                                                                                                                                                                                                                                            text  \
# 0                                                                                                                                                                                                                             Coronavirus: No new deaths and 727 new cases confirmed in Ireland
# 1                                                                                            This was definitely a Grenade tweet just lobbed into twittersphere for people to go mad at.There can’t be anyway that you think the sectors you’ve mentioned have shaped the covid response/policy
# 2                                                                                                                                                                                                                                                      Everyone in Kolkata now is Covid Aladin.
# 3                                                                                    Becky's mother hasn't held her granddaughter yet.Balor's father went through COVID-19 and triple heart bypass surgery.Both parents are IT to each of them.And I am sure there's a great many stories more.
# 4                                                                                                                                                                    2020 has been crazy year, bought a house at 27 with my partner, Got married and Got covid. it's been a rollercoaster year.
# ...                                                                                                                                                                                                                                                                                         ...
# 51995  Of course, because who doesn't love a leader who failed to prevent a second COVID-19 wave he knew was coming? It's not like other countries have gotten a handle on this pandemic, proving it's possible while exposing Canada's response as a woefully inadequate deadly embarrassment.
# 51996                                                                                                                                                                                                             French President Emmanuel Macron tests positive for coronavirus - National |
# 51997                               My god. Will somebody please help untwist his shorts? You sit on your fucking hands instead of helping Americans deal with Covid, you tolerate Trump's racism and sexism but you get bent out of shape because you're called a fucker? You fucking #fucker.
# 51998                                                                                               Those who were abandoning wells anyway [are] the ones who are taking advantage of this federal program, Dorin told Global News in an interview. In other words we're not creating any jobs.
# 51999                                                                                                                                                                                                              #MidnightMass Covid safety zones in Vancouver. Red zone = performance zone.
#
#                                                                                                                                                                                                clean_text  \
# 0                                                                                                                                                  coronavirus new deaths 727 new cases confirmed ireland
# 1                                                             definitely grenade tweet lobbed twittersphere people go mad atthere can’t anyway think sectors you’ve mentioned shaped covid responsepolicy
# 2                                                                                                                                                                           everyone kolkata covid aladin
# 3                                                     beckys mother hasnt held granddaughter yetbalors father went covid19 triple heart bypass surgeryboth parents themand sure theres great many stories
# 4                                                                                                                        2020 crazy year bought house 27 partner got married got covid rollercoaster year
# ...                                                                                                                                                                                                   ...
# 51995  course doesnt love leader failed prevent second covid19 wave knew coming like countries gotten handle pandemic proving possible exposing canadas response woefully inadequate deadly embarrassment
# 51996                                                                                                                                french president emmanuel macron tests positive coronavirus national
# 51997                      god somebody please help untwist shorts sit fucking hands instead helping americans deal covid tolerate trumps racism sexism get bent shape youre called fucker fucking fucker
# 51998                                                                                  abandoning wells anyway ones taking advantage federal program dorin told global news interview words creating jobs
# 51999                                                                                                                                 midnightmass covid safety zones vancouver red zone performance zone
#
#        class  \
# 0         -1
# 1         -1
# 2          0
# 3          1
# 4         -1
# ...      ...
# 51995     -1
# 51996      1
# 51997     -1
# 51998     -1
# 51999      1
#
#                                                                                                                                                                                                 new_treat
# 0                                                                                                                                                  coronavirus new deaths 727 new cases confirmed ireland
# 1                                                             definitely grenade tweet lobbed twittersphere people go mad atthere can’t anyway think sectors you’ve mentioned shaped covid responsepolicy
# 2                                                                                                                                                                           everyone kolkata covid aladin
# 3                                                     beckys mother hasnt held granddaughter yetbalors father went covid19 triple heart bypass surgeryboth parents themand sure theres great many stories
# 4                                                                                                                        2020 crazy year bought house 27 partner got married got covid rollercoaster year
# ...                                                                                                                                                                                                   ...
# 51995  course doesnt love leader failed prevent second covid19 wave knew coming like countries gotten handle pandemic proving possible exposing canadas response woefully inadequate deadly embarrassment
# 51996                                                                                                                                french president emmanuel macron tests positive coronavirus national
# 51997                      god somebody please help untwist shorts sit fucking hands instead helping americans deal covid tolerate trumps racism sexism get bent shape youre called fucker fucking fucker
# 51998                                                                                  abandoning wells anyway ones taking advantage federal program dorin told global news interview words creating jobs
# 51999                                                                                                                                 midnightmass covid safety zones vancouver red zone performance zone
#
# [52000 rows x 4 columns]

# %%
root_tweet_clean[ root_tweet_clean['clean_text'] != root_tweet_clean['new_treat'] ]
# Out:
#                  text clean_text  class new_treat
# 790             This.        NaN      0       nan
# 1443              NaN        NaN      0       nan
# 4535              NaN        NaN      0       nan
# 4542              NaN        NaN      0       nan
# 5865              NaN        NaN      0       nan
# 5867              NaN        NaN      0       nan
# 6954              NaN        NaN      0       nan
# 7924    More of this?        NaN      0       nan
# 7926    More of this?        NaN      0       nan
# 7931    More of this?        NaN      0       nan
# 14155             NaN        NaN      0       nan
# 21441             NaN        NaN      0       nan
# 22442             NaN        NaN      0       nan
# 25731             NaN        NaN      0       nan
# 26172             NaN        NaN      0       nan
# 29183             NaN        NaN      0       nan
# 30153  And now, THIS:        NaN      0       nan
# 33193             NaN        NaN      0       nan
# 39078      It's here.        NaN      0       nan
# 39267             NaN        NaN      0       nan
# 39473         re this        NaN      0       nan
# 39485             NaN        NaN      0       nan
# 40704             NaN        NaN      0       nan
# 41700             NaN        NaN      0       nan
# 41751     And this...        NaN      0       nan
# 42332             NaN        NaN      0       nan
# 44952             NaN        NaN      0       nan
# 45169     what the..?        NaN      0       nan
# 45296             NaN        NaN      0       nan
# 47217             NaN        NaN      0       nan
# 48868             NaN        NaN      0       nan

# %%
root_tweet_clean.iloc[790]
# Out:
# text          This.
# clean_text      NaN
# class             0
# new_treat       nan
# Name: 790, dtype: object

# %%
original = pd.read_csv('Datos1_Kike/allTweets.csv')

# %%
print(original.iloc[51998])
# Out:
# text    "Those who were abandoning wells anyway [are] the ones who are taking advantage of this federal program," Dorin told Global News in an interview. "In other words we're not creating any jobs."\nhttps://t.co/OBtWAyVQND
# Name: 51998, dtype: object

# %%
root_tweet_clean[
    root_tweet_clean['clean_text'].astype('str').str.contains('corona') |
    root_tweet_clean['clean_text'].astype('str').str.contains('cov')
    ]
# Out:
#                                                                                                                                                                                                                                                                                            text  \
# 0                                                                                                                                                                                                                             Coronavirus: No new deaths and 727 new cases confirmed in Ireland
# 1                                                                                            This was definitely a Grenade tweet just lobbed into twittersphere for people to go mad at.There can’t be anyway that you think the sectors you’ve mentioned have shaped the covid response/policy
# 2                                                                                                                                                                                                                                                      Everyone in Kolkata now is Covid Aladin.
# 3                                                                                    Becky's mother hasn't held her granddaughter yet.Balor's father went through COVID-19 and triple heart bypass surgery.Both parents are IT to each of them.And I am sure there's a great many stories more.
# 4                                                                                                                                                                    2020 has been crazy year, bought a house at 27 with my partner, Got married and Got covid. it's been a rollercoaster year.
# ...                                                                                                                                                                                                                                                                                         ...
# 51994                                                                                      Covid19 cases are on the rise.We need everyone’s help to save lives &amp; livelihoods. Please stay home as much as possible and wear a mask if you must go out.  Do not gather with other households
# 51995  Of course, because who doesn't love a leader who failed to prevent a second COVID-19 wave he knew was coming? It's not like other countries have gotten a handle on this pandemic, proving it's possible while exposing Canada's response as a woefully inadequate deadly embarrassment.
# 51996                                                                                                                                                                                                             French President Emmanuel Macron tests positive for coronavirus - National |
# 51997                               My god. Will somebody please help untwist his shorts? You sit on your fucking hands instead of helping Americans deal with Covid, you tolerate Trump's racism and sexism but you get bent out of shape because you're called a fucker? You fucking #fucker.
# 51999                                                                                                                                                                                                              #MidnightMass Covid safety zones in Vancouver. Red zone = performance zone.
#
#                                                                                                                                                                                                clean_text  \
# 0                                                                                                                                                  coronavirus new deaths 727 new cases confirmed ireland
# 1                                                             definitely grenade tweet lobbed twittersphere people go mad atthere can’t anyway think sectors you’ve mentioned shaped covid responsepolicy
# 2                                                                                                                                                                           everyone kolkata covid aladin
# 3                                                     beckys mother hasnt held granddaughter yetbalors father went covid19 triple heart bypass surgeryboth parents themand sure theres great many stories
# 4                                                                                                                        2020 crazy year bought house 27 partner got married got covid rollercoaster year
# ...                                                                                                                                                                                                   ...
# 51994                                                             covid19 cases risewe need everyone’s help save lives amp livelihoods please stay home much possible wear mask must go gather households
# 51995  course doesnt love leader failed prevent second covid19 wave knew coming like countries gotten handle pandemic proving possible exposing canadas response woefully inadequate deadly embarrassment
# 51996                                                                                                                                french president emmanuel macron tests positive coronavirus national
# 51997                      god somebody please help untwist shorts sit fucking hands instead helping americans deal covid tolerate trumps racism sexism get bent shape youre called fucker fucking fucker
# 51999                                                                                                                                 midnightmass covid safety zones vancouver red zone performance zone
#
#        class  \
# 0         -1
# 1         -1
# 2          0
# 3          1
# 4         -1
# ...      ...
# 51994      1
# 51995     -1
# 51996      1
# 51997     -1
# 51999      1
#
#                                                                                                                                                                                                 new_treat
# 0                                                                                                                                                  coronavirus new deaths 727 new cases confirmed ireland
# 1                                                             definitely grenade tweet lobbed twittersphere people go mad atthere can’t anyway think sectors you’ve mentioned shaped covid responsepolicy
# 2                                                                                                                                                                           everyone kolkata covid aladin
# 3                                                     beckys mother hasnt held granddaughter yetbalors father went covid19 triple heart bypass surgeryboth parents themand sure theres great many stories
# 4                                                                                                                        2020 crazy year bought house 27 partner got married got covid rollercoaster year
# ...                                                                                                                                                                                                   ...
# 51994                                                             covid19 cases risewe need everyone’s help save lives amp livelihoods please stay home much possible wear mask must go gather households
# 51995  course doesnt love leader failed prevent second covid19 wave knew coming like countries gotten handle pandemic proving possible exposing canadas response woefully inadequate deadly embarrassment
# 51996                                                                                                                                french president emmanuel macron tests positive coronavirus national
# 51997                      god somebody please help untwist shorts sit fucking hands instead helping americans deal covid tolerate trumps racism sexism get bent shape youre called fucker fucking fucker
# 51999                                                                                                                                 midnightmass covid safety zones vancouver red zone performance zone
#
# [44424 rows x 4 columns]

# %%
validation = pd.read_csv('Datos2/twtsForTensi1_out.txt',sep='\t')

# %%
rnd1 = random.randint(0,len(validation[validation.Overall == -1]))
mens1,etiqueta1 = validation.Text[validation.Overall == -1].iloc[rnd1],validation.Overall[validation.Overall == -1].iloc[rnd1]
pred1 = pipeline.predict([mens1])
print("Predicción 1 en validación", pred1)
print("Predicción 1 valor real", etiqueta1)

rnd2 = random.randint(0,len(validation[validation.Overall == 0]))
mens2,etiqueta2 = validation.Text[validation.Overall == 0].iloc[rnd2],validation.Overall[validation.Overall == 0].iloc[rnd2]
pred2 = pipeline.predict([mens2])
print("Predicción 1 en validación", pred2)
print("Predicción 1 valor real", etiqueta2)

rnd3 = random.randint(0,len(validation[validation.Overall == 1]))
mens3,etiqueta3 = validation.Text[validation.Overall == 1].iloc[rnd3],validation.Overall[validation.Overall == 1].iloc[rnd3]
pred3 = pipeline.predict([mens3])
print("Predicción 1 en validación", pred3)
print("Predicción 1 valor real", etiqueta3)

print(rnd1,rnd2, rnd3)
# Out:
# Predicción 1 en validación [-1]
# Predicción 1 valor real -1
# Predicción 1 en validación [0]
# Predicción 1 valor real 0
# Predicción 1 en validación [-1]
# Predicción 1 valor real 1
# 3471 389 1268

# %% [markdown]
# ## Saving, loading and putting to the test the Transformers and the Model

# %%
pickle.dump(tfidf_transformer, open("tfidf_AnxieTweet.pickle", "wb"))

# %%
tfidf_saved = pickle.load(open("tfidf_AnxieTweet.pickle", "rb"))

# %%
test_text = "@Anti_SS_69 @alan_gable @cathymg8820 @Kelleyrose20 @NotThisPussyCat @garym27 @AnneJohnson12 @LetsGetBusy_ @ThatsJaimeLeigh @OlivviaDay @Beurybarbara Funny thing is; it's the Cult of Trump Devotees most at risk of catching the Covid-19; due to their extreme ignorance!"

# %%
pickle.dump(bow_transformer, open("bow_AnxieTweet.pickle", "wb"))

# %%
bow_saved = pickle.load(open("bow_AnxieTweet.pickle", "rb"))

# %%
print(bow_saved.transform([test_text]))
# Out:
#   (0, 1030)	1
#   (0, 6714)	1
#   (0, 11145)	1
#   (0, 14513)	1
#   (0, 15724)	1
#   (0, 17438)	1
#   (0, 19044)	1
#   (0, 21314)	1
#   (0, 23562)	1
#   (0, 27764)	1
#   (0, 29304)	1
#   (0, 29432)	1
#   (0, 36259)	1
#   (0, 38757)	2
#   (0, 46265)	1
#   (0, 53524)	2
#   (0, 53633)	1
#   (0, 53869)	1
#   (0, 54429)	1
#   (0, 55398)	1

# %%
print(bow_transformer.transform([test_text]))
# Out:
#   (0, 5522)	1
#   (0, 11553)	1
#   (0, 13065)	1
#   (0, 13199)	1
#   (0, 15334)	1
#   (0, 18274)	1
#   (0, 22853)	1
#   (0, 27211)	1
#   (0, 28777)	1
#   (0, 28961)	1
#   (0, 32916)	1
#   (0, 39454)	1
#   (0, 39929)	1
#   (0, 50169)	1
#   (0, 53633)	1
#   (0, 54429)	1
#   (0, 54507)	1

# %%
print(tfidf_saved.transform(bow_saved.transform([test_text])))
# Out:
#   (0, 55398)	0.1224913145559297
#   (0, 54429)	0.2060506485171485
#   (0, 53869)	0.14683811473007946
#   (0, 53633)	0.25675002215927445
#   (0, 53524)	0.334257663708377
#   (0, 46265)	0.1463484012046026
#   (0, 38757)	0.42701940581308634
#   (0, 36259)	0.27047423163853973
#   (0, 29432)	0.11753248957716222
#   (0, 29304)	0.2114420120916078
#   (0, 27764)	0.22635295736657304
#   (0, 23562)	0.1951571306094435
#   (0, 21314)	0.20773036550081206
#   (0, 19044)	0.1252414461842721
#   (0, 17438)	0.2890968235043007
#   (0, 15724)	0.23213229477230418
#   (0, 14513)	0.047631360470160644
#   (0, 11145)	0.19801799256141545
#   (0, 6714)	0.2409581218650738
#   (0, 1030)	0.1507485089894769

# %%
print(tfidf_transformer.transform(bow_saved.transform([test_text])))
# Out:
#   (0, 54507)	0.1890760637726648
#   (0, 54429)	0.23808326112397696
#   (0, 53633)	0.296664354173319
#   (0, 50169)	0.25441498932444295
#   (0, 39929)	0.31818201225344983
#   (0, 39454)	0.2473290604410699
#   (0, 32916)	0.1857665331400165
#   (0, 28961)	0.2078118540986061
#   (0, 28777)	0.3035914928454932
#   (0, 27211)	0.2605561766852315
#   (0, 22853)	0.2486227233997797
#   (0, 18274)	0.26255967301297206
#   (0, 15334)	0.22337537515427633
#   (0, 13199)	0.20558740723951802
#   (0, 13065)	0.17109980680961404
#   (0, 11553)	0.22004610726212853
#   (0, 5522)	0.23250186833449943

# %%
stress_detect_model.predict(tfidf_transformer.transform(bow_saved.transform([test_text])))
# Out:
# array([-1])

# %%
pickle.dump(stress_detect_model, open("anxieTweet_Prediction_Model.pickle", "wb"))

# %%
svd_Pred_Mdl = pickle.load(open("anxieTweet_Prediction_Model.pickle", "rb"))

# %%
svd_Pred_Mdl.predict(tfidf_transformer.transform(bow_saved.transform([test_text])))
# Out:
# array([-1])

# %%
print(tfidf_transformer.transform(bow_saved.transform([test_text])))
# Out:
#   (0, 54507)	0.1890760637726648
#   (0, 54429)	0.23808326112397696
#   (0, 53633)	0.296664354173319
#   (0, 50169)	0.25441498932444295
#   (0, 39929)	0.31818201225344983
#   (0, 39454)	0.2473290604410699
#   (0, 32916)	0.1857665331400165
#   (0, 28961)	0.2078118540986061
#   (0, 28777)	0.3035914928454932
#   (0, 27211)	0.2605561766852315
#   (0, 22853)	0.2486227233997797
#   (0, 18274)	0.26255967301297206
#   (0, 15334)	0.22337537515427633
#   (0, 13199)	0.20558740723951802
#   (0, 13065)	0.17109980680961404
#   (0, 11553)	0.22004610726212853
#   (0, 5522)	0.23250186833449943
